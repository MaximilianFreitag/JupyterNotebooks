# %% [markdown]
# ### 4 plots in 1

# %%
import numpy as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
# %matplotlib inline


a = [1.02, .95, .87, .77, .67, .46, .74, .60]
b = [0.39, .32, .27, .22, .18, .15, .13, .12]
c = [0.49, .42, .37, .32, .28, .35, .33, .52]
d = [0.29, .52, .47, .52, .58, .35, .43, .32]

figure(num=None, figsize=(12, 8), dpi=50, facecolor='w', edgecolor='k')



plt.plot(a, 'r') # plotting a separately 
plt.plot(b, 'b') # plotting b separately
plt.plot(c, 'g') # plotting c separately 
plt.plot(d, 'y') # plotting d separately 



plt.title('Title of your graph')
plt.xlabel('Something X')
plt.ylabel('Jahre')

   

plt.show()

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %% [markdown]
# ### 4 different plots in 1

# %%
import numpy as np
from numpy import e, pi, sin, exp, cos
import matplotlib.pyplot as plt


a = [1.02, .95, .87, .77, .67, .46, .74, .60]
b = [0.39, .32, .27, .22, .18, .15, .13, .12]
c = [0.49, .42, .37, .32, .28, .35, .33, .52]
d = [0.29, .52, .47, .52, .58, .35, .43, .32]


python_course_green = "#476042"
fig = plt.figure(figsize=(6, 4))

#t = np.arange(-5.0, 1.0, 0.1)

sub1 = fig.add_subplot(221) # instead of plt.subplot(2, 2, 1)
sub1.set_title('Something A') # non OOP: plt.title('The function f')
sub1.plot(a)


sub2 = fig.add_subplot(222, facecolor="lightgrey")
sub2.set_title('Something B')
sub2.plot(b)


t = np.arange(-3.0, 2.0, 0.02)
sub3 = fig.add_subplot(223)
sub3.set_title('Something C')
sub3.plot(c)

t = np.arange(-0.2, 0.2, 0.001)
sub4 = fig.add_subplot(224, facecolor="lightgrey")
sub4.set_title('Something D')
sub4.plot(d)



plt.tight_layout()
plt.show()

# %%
import numpy as np 
from matplotlib import pyplot as plt 

x = np.arange(12,30) 
y = 2 * x + 5 
plt.title("Matplotlib demo") 
plt.xlabel("x axis caption") 
plt.ylabel("y axis caption") 
plt.plot(x,y) 
plt.show()

# %%
import matplotlib.pyplot as plt
   
Jahre = [2002,2003,2004,2005,2006,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
Unemployment_Rate = [4048,4389,4645,4740,5109,4602,5072,4300,3788,3625,3722,3625,3643,3711,3830,3753,3893,4461]
plt.plot(Jahre, Unemployment_Rate, marker='o')
plt.title('Wie viel Strom verbrauchen wir jährlich?', fontsize=18)
#plt.figure(figsize=(19, 19))
plt.grid(True)
plt.xlabel('Jahre')
plt.ylabel('Kilowatstunde KwH')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# importing the matplotlib library
import matplotlib.pyplot as plt
  
# values on x-axis
x = [2002,2003,2004,2005,2006,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
# values on y-axis
yZZ = [4048,4389,4645,4740,5109,4602,5072,4300,3788,3625,3722,3625,3643,3711,3830,3753,3893,4461]
  
# naming the x and y axis
#plt.xlabel('x - axis')
#plt.ylabel('y - axis')
  
# plotting a line plot with it's default size
#print("Plot in it's default size: ")
#plt.plot(x, y, marker='o')
#plt.show()
  
# plotting a line plot after changing it's width and height
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.grid(True)
plt.title('Stromverbrauch pro Jahr in kwH', fontsize=18)
plt.xlabel('Jahre', fontsize=12)
plt.ylabel('Kilowattstunde KwH', fontsize=12)
plt.plot(x, yZZ, marker='o')
plt.show()

coef = np.polyfit(x,yZZ,4)
poly1d_fn = np.poly1d(coef) 
plt.plot(x,yZZ, 'yo', x, poly1d_fn(x), '--k')

# %%
import numpy as np
import matplotlib.pyplot as plt

# importing the matplotlib library
import matplotlib.pyplot as plt
  
# values on x-axis
x = [2002,2003,2004,2005,2006,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
# values on y-axis
yZ = [606,687,751,830,908,921,1039,886,854,839,965,982,986,1003,990,971,1081,1250]
  
# naming the x and y axis
#plt.xlabel('x - axis')
#plt.ylabel('y - axis')
  
# plotting a line plot with it's default size
#print("Plot in it's default size: ")
#plt.plot(x, y, marker='o')
#plt.show()
  
# plotting a line plot after changing it's width and height
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.grid(True)
plt.title('Strompreis pro Jahr', fontsize=18)
plt.xlabel('Jahre', fontsize=12)
plt.ylabel('Kilowattstunde KwH', fontsize=12)
plt.plot(x, y, marker='o')
plt.show()

coef = np.polyfit(x,yZ,4)
poly1d_fn = np.poly1d(coef) 
plt.plot(x,yZ, 'yo', x, poly1d_fn(x), '--k')

# %%
# values on x-axis
x = [2002,2003,2004,2005,2006,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
# values on y-axis
y = [606,687,751,830,908,921,1039,886,854,839,965,982,986,1003,990,971,1081,1250]
yZ = [1048,1389,1645,1740,2109,1602,2072,1300,788,625,722,625,643,711,830,753,893,1461]
# naming the x and y axis
#plt.xlabel('x - axis')
#plt.ylabel('y - axis')
  
# plotting a line plot with it's default size
#print("Plot in it's default size: ")
#plt.plot(x, y, marker='o')
#plt.show()
  
# plotting a line plot after changing it's width and height
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.grid(True)
plt.title('Vergleich: Preis und Verbrauch', fontsize=18)
plt.xlabel('Jahre', fontsize=12)
plt.ylabel('-', fontsize=12)
plt.plot(x, y, marker='o')
plt.plot(x, yZ, marker='o')
plt.gca().legend(('Preis','Verbrauch'))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# values on x-axis
x = [2000,2001,2002,2003,2004,2005,2006,2008,2009,2010,2011,2012,2014,2015,2016,2017,2018,2019,2020]
# values on y-axis
y_ErdgasVerbrauch = [17858,19182,19392,19830,21371,19205,15952,14150,16122,18145,11936,12420,12053,11374,14756,12335,11180,9528,10299]
#yZ = [1048,1389,1645,1740,2109,1602,2072,1300,788,625,722,625,643,711,830,753,893,1461]
# naming the x and y axis
#plt.xlabel('x - axis')
#plt.ylabel('y - axis')
  
# plotting a line plot with it's default size
#print("Plot in it's default size: ")
#plt.plot(x, y, marker='o')
#plt.show()
  
# plotting a line plot after changing it's width and height
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.grid(True)
plt.title('Erdgasverbrauch in kwH', fontsize=18)
plt.xlabel('Jahre', fontsize=12)
plt.ylabel('Kilowattstunde kwH', fontsize=12)
plt.plot(x, y_ErdgasVerbrauch, marker='o')
#plt.plot(x, yZ, marker='o')
#plt.gca().legend(('-','Verbrauch'))
plt.show()

coef = np.polyfit(x,y_ErdgasVerbrauch,4)
poly1d_fn = np.poly1d(coef) 
plt.plot(x,y_ErdgasVerbrauch, 'yo', x, poly1d_fn(x), '--k')

# %%
import numpy as np
import matplotlib.pyplot as plt

# values on x-axis
x = [2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
# values on y-axis
y_ErdgasPreis = [737,921,883,933,1015,1032,1028,825,1042,1219,1168,863,968,1001,944,900,1076,821,614,676,701]
#yZ = [1048,1389,1645,1740,2109,1602,2072,1300,788,625,722,625,643,711,830,753,893,1461]
# naming the x and y axis
#plt.xlabel('x - axis')
#plt.ylabel('y - axis')
  
# plotting a line plot with it's default size
#print("Plot in it's default size: ")
#plt.plot(x, y, marker='o')
#plt.show()
  
# plotting a line plot after changing it's width and height
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.grid(True)
plt.title('Bruttopreis Erdgas', fontsize=18)
plt.xlabel('Jahre', fontsize=12)
plt.ylabel('Brutto in €', fontsize=12)
plt.plot(x, y_ErdgasPreis, marker='o')
#plt.plot(x, yZ, marker='o')
#plt.gca().legend(('-','Verbrauch'))
plt.show()

coef = np.polyfit(x,y_ErdgasPreis,4)
poly1d_fn = np.poly1d(coef) 
plt.plot(x,y_ErdgasPreis, 'yo', x, poly1d_fn(x), '--k')

# %%
import numpy as np
import matplotlib.pyplot as plt

# values on x-axis
x = [2001,2002,2003,2004,2005,2006,2008,2009,2010,2011,2012,2014,2015,2016,2017,2018,2019,2020]
# values on y-axis
y_wasserVerbrauch = [127,122,155,152,173,168,141,159,137,133,136,141,139,136,144,140,133,144]
#yZ = [1048,1389,1645,1740,2109,1602,2072,1300,788,625,722,625,643,711,830,753,893,1461]
# naming the x and y axis
#plt.xlabel('x - axis')
#plt.ylabel('y - axis')
  
# plotting a line plot with it's default size
#print("Plot in it's default size: ")
#plt.plot(x, y, marker='o')
#plt.show()
  
# plotting a line plot after changing it's width and height
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.grid(True)
plt.title('Verbrauch Wasser in m*3', fontsize=18)
plt.xlabel('Jahre', fontsize=12)
plt.ylabel('Brutto in €', fontsize=12)
plt.plot(x, y_wasserVerbrauch, marker='o')
#plt.plot(x, yZ, marker='o')
#plt.gca().legend(('-','Verbrauch'))
plt.show()

coef = np.polyfit(x,y_wasserVerbrauch,4)
poly1d_fn = np.poly1d(coef) 
plt.plot(x,y_wasserVerbrauch, 'yo', x, poly1d_fn(x), '--k')

# %%
import numpy as np
import matplotlib.pyplot as plt

# values on x-axis
x = [2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
# values on y-axis
y_wasserPreis = [322,327,369,374,406,413,371,380,432,377,370,374,387,383,380,406,418,411,398,408]
#yZ = [1048,1389,1645,1740,2109,1602,2072,1300,788,625,722,625,643,711,830,753,893,1461]
# naming the x and y axis
#plt.xlabel('x - axis')
#plt.ylabel('y - axis')
  
# plotting a line plot with it's default size
#print("Plot in it's default size: ")
#plt.plot(x, y, marker='o')
#plt.show()
  
# plotting a line plot after changing it's width and height
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.grid(True)
plt.title('Wasserpreis in Brutto', fontsize=18)
plt.xlabel('Jahre', fontsize=12)
plt.ylabel('Brutto in €', fontsize=12)
plt.plot(x, y_wasserPreis, marker='o')
#plt.plot(x, yZ, marker='o')
#plt.gca().legend(('-','Verbrauch'))
plt.show()

coef = np.polyfit(x,y_wasserPreis,4)
poly1d_fn = np.poly1d(coef) 
plt.plot(x,y_wasserPreis, 'yo', x, poly1d_fn(x), '--k')

# %%
# values on x-axis
x = [2000,2001,2002,2003,2004,2005,2006,2008,2009,2010,2011,2012,2014,2015,2016,2017,2018,2019,2020]
# values on y-axis
y_WasserPreis = [92,202,207,249,254,386,293,260,312,257,250,254,263,260,286,298,291,278,288]
y_WasserVerbrauch = [70,127,122,155,152,173,168,141,159,137,133,136,141,139,136,144,140,133,144]
#yZ = [1048,1389,1645,1740,2109,1602,2072,1300,788,625,722,625,643,711,830,753,893,1461]
# naming the x and y axis
#plt.xlabel('x - axis')
#plt.ylabel('y - axis')

for i in y_WasserPreis:
    i = i - 50

# plotting a line plot with it's default size
#print("Plot in it's default size: ")
#plt.plot(x, y, marker='o')
#plt.show()
  
# plotting a line plot after changing it's width and height
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.grid(True)
plt.title('Vergleich: Wasserpreis vs Wasserverbrauch', fontsize=18)
plt.xlabel('Jahre', fontsize=12)
plt.ylabel('-', fontsize=12)
plt.plot(x, y_WasserPreis, marker='o')
plt.plot(x, y_WasserVerbrauch, marker='o')
plt.gca().legend(('Preis','Verbrauch'))
plt.show()

# %%
# values on x-axis
x = [2000,2001,2002,2003,2004,2005,2006,2008,2009,2010,2011,2012,2014,2015,2016,2017,2018,2019,2020]
# values on y-axis
y_ErdgasVerbrauch = [10858,12182,12392,12830,14371,12205,8952,7150,9122,11145,4936,5420,5053,4374,7756,5335,4180,2528,3299]
y_ErdgasPreis = [737,921,883,933,1015,1032,1028,1042,1219,1168,863,968,944,900,1076,821,614,676,701]
#yZ = [1048,1389,1645,1740,2109,1602,2072,1300,788,625,722,625,643,711,830,753,893,1461]
# naming the x and y axis
#plt.xlabel('x - axis')
#plt.ylabel('y - axis')
  
# plotting a line plot with it's default size
#print("Plot in it's default size: ")
#plt.plot(x, y, marker='o')
#plt.show()
  
# plotting a line plot after changing it's width and height
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.grid(True)
plt.title('Vergleich: Erdgasverbrauch vs Erdgaspreis', fontsize=18)
plt.xlabel('Jahre', fontsize=12)
plt.ylabel('Kilowattstunde kwH', fontsize=12)
plt.plot(x, y_ErdgasVerbrauch, marker='o')
plt.plot(x, y_ErdgasPreis, marker='o')
plt.gca().legend(('Verbrauch','Preis'))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# values on x-axis
x = [2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
# values on y-axis
y_gesamt = [1740,1816,1991,2141,2269,2349,2120,2344,2692,2431,2087,2182,2354,2310,2266,2485,2229,1996,2156,2359]

#yZ = [1048,1389,1645,1740,2109,1602,2072,1300,788,625,722,625,643,711,830,753,893,1461]
# naming the x and y axis
#plt.xlabel('x - axis')
#plt.ylabel('y - axis')
  
# plotting a line plot with it's default size
#print("Plot in it's default size: ")
#plt.plot(x, y, marker='o')
#plt.show()
  
# plotting a line plot after changing it's width and height
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.grid(True)
plt.title('Gesamtpreis: Strom, Erdgas, Wasser in €', fontsize=18)
plt.xlabel('Jahre', fontsize=12)
plt.ylabel('Gesamtpreis in €', fontsize=12)
plt.plot(x, y_gesamt, marker='o')

#plt.gca().legend(('-','Preis'))
plt.show()


coef = np.polyfit(x,y_gesamt,4)
poly1d_fn = np.poly1d(coef) 
plt.plot(x,y_gesamt, 'yo', x, poly1d_fn(x), '--k')

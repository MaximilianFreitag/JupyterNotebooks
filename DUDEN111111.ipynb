# %%
from urllib.request import urlopen
a = urlopen('http://www.netzmafia.de/software/wordlists/deutsch.txt').read()

#x = [i.replace('ae', 'ä') for i in a] 

print(x)
# Out:
# ['haloechen', 'Brätchen', 'tragoedie']

# %%
a = ['haloechen', 'Braetchen', 'tragoedie']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-6127418e36e0> in <module>
#       1 a = ['haloechen', 'Braetchen', 'tragoedie']
#       2
# ----> 3 z = [a.replace('ae', 'ä') for i in a]
#
# <ipython-input-4-6127418e36e0> in <listcomp>(.0)
#       1 a = ['haloechen', 'Braetchen', 'tragoedie']
#       2
# ----> 3 z = [a.replace('ae', 'ä') for i in a]
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
a = ['haloechen', 'Braetchen', 'tragoedie']

x = [i.replace('ae', 'ä') for i in a] 

print(x)
# Out:
# ['haloechen', 'Brätchen', 'tragoedie']

# %%
y = [i.replace('oe', 'ö') for i in x] 

print(y)
# Out:
# ['halöchen', 'Brätchen', 'tragödie']

# %%
import urllib3

word_site = "http://www.netzmafia.de/software/wordlists/deutsch.txt"

response = urllib3.urlopen(word_site)
txt = response.read()
WORDS = txt.splitlines()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-06b9dbf78fa5> in <module>
#       3 word_site = "http://www.netzmafia.de/software/wordlists/deutsch.txt"
#       4
# ----> 5 response = urllib3.urlopen(word_site)
#       6 txt = response.read()
#       7 WORDS = txt.splitlines()
#
# AttributeError: module 'urllib3' has no attribute 'urlopen'

# %%
import urllib3
http = urllib3.PoolManager()
r = http.request('GET', 'http://www.netzmafia.de/software/wordlists/deutsch.txt')


print(r)

# %%
import urllib3

# Creating a PoolManager instance for sending requests.
http = urllib3.PoolManager()

# Sending a GET request and getting back response as HTTPResponse object.
resp = http.request("GET", "http://www.netzmafia.de/software/wordlists/deutsch.txt")

# Print the returned data.
print(resp.data)
# b"User-agent: *\nDisallow: /deny\n"
# Out:
# b"ADA\nADAC\nAEG\nAG\nAI\nAIDS\nAP\nAPEX\nARD\nASTA\nAT\nATP\nAale\nAalen\nAals\nAas\nAase\nAases\nAasgeiern\nAasgeiers\nAbaenderung\nAbaenderungsantraege\nAbaenderungsantraegen\nAbaenderungsantrag\nAbaenderungsvorschlag\nAbakus\nAbarbeitung\nAbart\nAbarten\nAbbau\nAbbaumoeglichkeit\nAbbaumoeglichkeiten\nAbbaus\nAbberufungen\nAbbestellung\nAbbestellungen\nAbbilder\nAbbildern\nAbbildes\nAbbildungen\nAbbitte\nAbbittens\nAbblendlichter\nAbblendlichtern\nAbblendlichtes\nAbblendschaltern\nAbblendschalters\nAbbraende\nAbbruch\nAbbrucharbeit\nAbbrucharbeiten\nAbbruchobjekte\nAbbruchobjektes\nAbbruchs\nAbbruchunternehmens\nAbbruchunternehmer\nAbbruchunternehmers\nAbbuchungen\nAbdankung\nAbdankungen\nAbdeckern\nAbdeckers\nAbdeckplane\nAbdeckung\nAbdeckungen\nAbdichtung\nAbdrift\nAbdruck\nAbdruckes\nAbdrucks\nAbdruecke\nAbend\nAbendandachten\nAbendanzuege\nAbendanzug\nAbendblatt\nAbendblattes\nAbendbrot\nAbenddaemmerungen\nAbende\nAbenden\nAbendessens\nAbendgala\nAbendgarderobe\nAbendgebete\nA
# ...

# %%
with open('/Users/wiifreaki/Desktop/deutsch__.txt') as f:
    lines = f.readlines()
    
print(lines)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
